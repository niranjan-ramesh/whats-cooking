# %% [markdown]
# # Damn Delicious

# %% [raw]
# This notebook scrapes data from damndelicious.com. We used BeautifulSoup in entirety and generated two datasets: recipes and reviews

# %%
# Import statements
import os
import ast
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from urllib.request import Request, urlopen

# %%
# Get the Web content
def get_web_content(url):
    try:
        request = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        webContent = urlopen(request).read().decode('UTF-8')
        return webContent
    except Exception as e:
        print("Error in requesting web page: ", e)
        return False

# %% [markdown]
# ### Constants

# %%
# Get Current Directory Path
PATH = os.getcwd()
# URL to the website
INDEX_URL = "https://damndelicious.net/recipe-index/"
# Directory for recipes csv
DIR_PATH = PATH + "/datasets/"
# Create path if doesn't exists
if not os.path.exists(DIR_PATH):
        os.makedirs(DIR_PATH)

# %% [markdown]
# ### Columns

# %%
# Columns for the recipes dataset
recipe_columns = [
    'recipe_id',
    'title',
    'date_posted',
    'yields',
    'prep_time',
    'cook_time',
    'total_time',
    'ratings',
    'ratings_count',
    'n_ingredients',
    'ingredients',
    'n_steps',
    'directions',
    'nutrition',
    'tags'
]
# Columns for reviews dataset
review_columns = [
    "recipe_id",
    "username",
    "review_date",
    "rating",
    "review_text"
]

# %% [markdown]
# ### Scraping the Web Page

# %%
def read_recipe(url, recipe_id):
    # Empty DataFrame
    empty_df = pd.DataFrame([], columns=recipe_columns)
    # Empty Reviews DataFrame
    empty_reviews_df = pd.DataFrame([], columns=review_columns)
    # Tokens from url
    tokens = url.split('/')
    try:
        # Get the html page
        webContent = get_web_content(url)
        # Parse the html page
        soup = BeautifulSoup(webContent, 'html.parser')
        # Check if page contains a recipe
        recipe_content = soup.find('div', class_='recipe-content')
        if recipe_content == None:
            # Return empty as none found
            print("No Recipe Found in ", tokens[-2])
            return empty_df, False
        # Data for dataframe
        data = []
        data.append(recipe_id)
        review_data = []
        # Title
        title = ""
        title_h1 = soup.find('h1', class_="post-title")
        if title_h1 != None:
            title = title_h1.text
        data.append(title)
        # Date Posted
        date_posted = ""
        if len(tokens) == 8:
            date_posted = tokens[3]+"/"+tokens[4]+"/"+tokens[5]
            date_posted = datetime.strptime(date_posted, '%Y/%m/%d').isoformat()
        data.append(date_posted)
        # Yields and Time
        yields = ""
        prep_time = ""
        cook_time = ""
        total_time = ""
        # Get the Post Meta Time Section
        post_meta_time = soup.find('div', {"class":["time"]})
        if post_meta_time != None:
            time_p_tags = post_meta_time.find_all('p')
            for time_p in time_p_tags:
                if time_p != None:
                    strong = time_p.find('strong')
                    if strong != None:
                        keyword = strong.text[:-1]
                        if strong.text[:-1] == "Yield" :
                            yields = time_p.span.text
                        if strong.text[:-1] == "prep time" :
                            prep_time = time_p.span.text
                        if strong.text[:-1] == "cook time" :
                            cook_time = time_p.span.text
                        if strong.text[:-1] == "total time" :
                            total_time = time_p.span.text
        # Yields
        data.append(yields)
        # Prep Time
        data.append(prep_time)
        # Cook Time
        data.append(cook_time)
        # Total Time
        data.append(total_time)
        # Rating
        rating_average = ""
        ratings_average_span = soup.find('span', class_='wprm-recipe-rating-average')
        if ratings_average_span != None:
            rating_average = ratings_average_span.text.strip()
        data.append(rating_average)
        # Ratings Count
        ratings_count = ""
        ratings_count_span = soup.find('span', class_='wprm-recipe-rating-count')
        if ratings_count_span != None:
            ratings_count = ratings_count_span.text.strip()
        data.append(ratings_count)
        # Ingredients
        ingredients = []
        ingredients_li = soup.find_all('li', itemprop="ingredients")
        for ingredient in ingredients_li:
            ingredients.append(ingredient.text.strip())
        data.append(len(ingredients))
        data.append(ingredients)
        # Directions
        directions = []
        directions_div = soup.find('div', class_="instructions")
        if directions_div != None:
            directions_li = directions_div.find_all('li')
            for direction in directions_li:
                if direction != None:
                    directions.append(direction.text)
        data.append(len(directions))
        data.append(directions)
        # Reviews 
        comments_li = soup.find_all('li', {'class':['depth-1']})
        if comments_li != None:
            for comment_li in comments_li:
                review = []
                username = ""
                rating = ""
                review_date = ""
                comments = ""
                comment_meta = comment_li.div.find('div', class_="comment-meta")
                if comment_meta != None:
                    username = comment_meta.find('strong').text
                if comment_meta.a.time != None:
                    review_date = comment_meta.a.time['datetime']
                comment_cont = comment_li.div.find('div', class_="comment-content")
                if comment_cont != None:
                    comment_rating = comment_cont.find('div', class_="wpsso-rar")
                    if comment_rating != None:
                        comment_rating = comment_rating.div
                        if comment_rating != None:
                            rating = comment_rating.text
                    comment_ps = comment_cont.find_all('p')
                    for p in comment_ps:
                        if p != None:
                            comment = p.text.strip()
                            if len(comment) > 0:
                                comments = comments + " " + comment
                    review.append(recipe_id)
                    review.append(username)
                    review.append(review_date)
                    review.append(rating)
                    review.append(comments.strip())
                    review_data.append(review)
        # Nutrition
        nutrition = []
        nutrition_div = soup.find('div', class_="wp-nutrition-label")
        if nutrition_div != None:
            span_left = nutrition_div.find_all('span', class_='f-left')
            for span in span_left:
                if span != None:
                    pairs = span.text.strip()
                    pairs = pairs.rsplit(" ", 1)
                    nutrition.append([pairs[0], pairs[1].strip()])
        data.append(nutrition)
        # Categories
        categories = []
        categories_a = soup.find_all('a', rel="category")
        for category in categories_a:
            if category != None:
                categories.append(category.text)
        data.append(categories)
        # Create a dataframe
        recipe_df = pd.DataFrame(data=[data], columns=recipe_columns)
        review_df = pd.DataFrame(data=review_data, columns=review_columns)
        #Processing reviews
        review_df['rating'] = review_df['rating'].str.split(" ").str[1]
        review_df['rating'] = review_df['rating'].fillna("")
        # Success Message
        print("Recipe Loaded successfully: ", tokens[-2])
        # Return statement
        return recipe_df, review_df, True
    except Exception as e:
        print("Error in loading Recipe: ", tokens[-2])
        print("Error in loading Web page: ", e)
        return empty_df, empty_reviews_df, False

# %% [markdown]
# ### Testing Web scraping of one recipe

# %%
# Test Case
recipe_url = "https://damndelicious.net/2015/03/20/lemon-chicken-with-asparagus-and-potatoes/"
result, review, success = read_recipe(recipe_url, 1)
print(result, review, success)
# Out:
# Recipe Loaded successfully:  lemon-chicken-with-asparagus-and-potatoes
#    recipe_id                                      title          date_posted  \
# 0          1  Lemon Chicken with Asparagus and Potatoes  2015-03-20T00:00:00
#
#        yields   prep_time   cook_time         total_time ratings  \
# 49          1                              Liz
# 50          1  Kathy @ Beyond the Chicken Coop
# 51          1              Laura (Tutti Dolci)
#
#    rating                                        review_text
# 0       5  Loved by my family!  I was worried that I put ...
# 1          I parboiled the potatoes, but I still added to...
# 2       5  My family and friends love this meal! I’ve mad...
# 3       5  So damn delicious!! I added minced garlic to t...
# 4          Unfortunately it turned out rather bland for m...
# 5          Do you all drain the pot of the chicken grease...
# 6          I made this tonight and it was everything I wa...
# 7          Very good!! My husband loved it too, I served ...
# 8          I made this dish tonight and my husband loved ...
# 9          Love love one skillet dishes.  This recipe is ...
# 10         I made this last night and it was absolutely d...
# 11         I.made this today with wings and fingerling po...
# 12         So you have me a base line for my boneless chi...
# 13                                   how can i print this ??
# 14         I’ve made this dish multiple times now and it’...
# 15         This is incredible! Especially when  asparagus...
# 16         This flavor was wonderful and all the componen...
# 17           Made this for dinner tonight. It was delicious.
# 18         What would be a good substitute for the mustar...
# 19         Healthy Update!!!! So this is my new favorite ...
# 20         I love this recipe! I have made 5 times in a m...
# 21         I just made this recipe tonight. The thighs I ...
# 22         Love the idea of this, but I can’t stand the f...
# 23         If you are using boneless chicken how many oz ...
# 24         I do the cooking in my home and this has to ra...
# 25         I made this tonight and it was delicious. I do...
# 26         This recipe looks so yummy; I’ll be making it ...
# 27         Thank you for another AMAZING recipe! My husba...
# 28         Made this tonight…..so, so good!!!  Made extra...
# 29         I’ve never moved a skillet from stove to oven....
# 30         loved the veggies in this recipe, but i didn’t...
# 31         Anyone having to cook chicken longer – I had m...
# 32         I used boneless to save some calories. It wasn...
# 33         love the simplicity of this dish, and not to m...
# 34         Great recipe – Bone in chicken thighs are my f...
# 35         This recipe doesn’t make a lot of sense… Am I ...
# 36         I made this tonight, both hubby and I loved it...
# 37         Thanks for the recipe, I tried it tonight and ...
# 38         This recipe is so easy and delicious.  Just go...
# 39         hi, this looks amazing and I’m prepping this t...
# 40         Made this last night and it was incredible.  S...
# 41         I think I will blanch the asparagus and add it...
# 42         Oops?  I hit send too quick.  What are the fla...
# 43         Two cups of potato doesn’t really sound like e...
# 44         I love the way you cook! Just found your blog,...
# 45         Love this skillet meal idea! It looks perfectl...
# 46         Delicious! Beautiful photos as well. I worry t...
# 47              So pretty! And I love skillet meals. EASY. 🙂
# 48                                 Yum! Trying this tonight!
# 49                            Thank you for the nice recipe.
# 50         Love one pot meals.  This one looks beautiful....
# 51         This is the perfect meal spring, love the vegg...   True

# %% [markdown]
# ### Getting Recipes for Each Ingredient

# %%
def get_recipes_by_ingredient(url, title_list, count):
    # Ingredient's recipes DataFrame 
    recipes_by_ingredient_df = pd.DataFrame([], columns=recipe_columns)
    reviews_by_ingredient_df = pd.DataFrame([], columns=review_columns)
    try:    
        # Get the html page
        webContent = get_web_content(url)
        # Parse the html page
        soup = BeautifulSoup(webContent, 'html.parser')
        # Get all the recipes for the ingredient
        archives = soup.find('div', class_='archives')
        if archives != None:
            archive_posts = archives.find_all('div', 'archive-post')
            for post in archive_posts:
                if post != None:
                    post_a = post.find('a')
                    if post_a != None:
                        title = post_a['title']
                        # Check for duplication of recipes
                        if title not in title_list:
                            recipe_url = post_a['href']
                            recipe_ingredient_df, review_ingredient_df, success = read_recipe(recipe_url, count)
                            count += 1
                            if success:
                                title_list.append(title)
                                recipes_by_ingredient_df = pd.concat\
                                ([recipes_by_ingredient_df, recipe_ingredient_df], ignore_index=True)
                                reviews_by_ingredient_df = pd.concat\
                                ([reviews_by_ingredient_df, review_ingredient_df], ignore_index=True)
    except Exception as e:
        print("Error in loading recipes from page: ", url)
        print("Error: ", e)
    finally:
        return recipes_by_ingredient_df, reviews_by_ingredient_df, count

# %% [markdown]
# ### Testing for one ingredient

# %%
# Test for recipes by ingredients
tag_url = "https://damndelicious.net/tag/asparagus/"
result = get_recipes_by_ingredient(tag_url, [])
# print(result)
# Out:
# Recipe Loaded successfully:  bacon-wrapped-asparagus
# Recipe Loaded successfully:  prosciutto-wrapped-asparagus
# Recipe Loaded successfully:  asparagus-tart-with-balsamic-reduction
# Recipe Loaded successfully:  veggie-flatbread-pizza
# No Recipe Found in  creamy-meyer-lemon-pasta
# Error in loading recipes from page:  https://damndelicious.net/tag/asparagus/
# Error:  not enough values to unpack (expected 3, got 2)

# %% [markdown]
# ### Get Ingredients List

# %%
def get_ingredients_list(url):
    # List of Lead Ingredients Title and URL
    ingredients_list = []
    try:
        # Get the html page
        webContent = get_web_content(url)
        # Parse the html page
        soup = BeautifulSoup(webContent, 'html.parser')
        # <Li> List
        ingredients_li = []
        # Get all the archives <UL> Tags
        archivelist_ul = soup.find_all('ul', 'archiveslist')
        for archive in archivelist_ul:
            if archive != None:
                archive_li = archive.find_all('li')
                ingredients_li = ingredients_li + archive_li
        # Get the Ingredients URL and Title
        for ingredient in ingredients_li:
            if ingredient != None:
                ingredient_a = ingredient.find('a')
                if ingredient_a != None:
                    ingredients_list.append([ingredient_a['title'], ingredient_a['href']])
    except Exception as e:
        print("Error in Loading the index page: ", e)
    finally:
        return ingredients_list

# %% [markdown]
# ### Merging All Ingredients Recipes into One

# %%
def scrape_dd():
    # The Index of all recipes
    index_url = "https://damndelicious.net/recipe-index/"
    try:
        ingredients_list = get_ingredients_list(index_url)
    except:
        print("Error in getting ingredients list! Terminating..")
        exit()
    # Titles of all recipes we find
    title_list = []
    # Final Dataframe
    damn_delicious_recipes_df = pd.DataFrame([], columns=recipe_columns)
    damn_delicious_reviews_df = pd.DataFrame([], columns=review_columns)
    print("Start..")
    count = 0
    # Get Recipes for each ingredient
    for ingredient in ingredients_list:
        # Ingredient Details
        ingredient_title = ingredient[0]
        ingredient_url = ingredient[1]
        print("##################################################")
        print("Reading recipes for Ingredient: ", ingredient_title)
        print("##################################################")
        try:
            ingredient_recipe_df, ingredient_review_df, count = get_recipes_by_ingredient(ingredient_url, title_list, count)
        except Exception as e: 
            print("##################################################")
            print("Error in Reading recipes for Ingredient: ", ingredient_title)
            print("Error = ", e)
            print("##################################################")
        print("##################################################")
        print("Completed reading recipes for Ingredient: ", ingredient_title)
        print("##################################################")
        try:
            damn_delicious_recipes_df = pd.concat([damn_delicious_recipes_df, ingredient_recipe_df], ignore_index=True)
            damn_delicious_reviews_df = pd.concat([damn_delicious_reviews_df, ingredient_review_df], ignore_index=True)
        except Exception as e:
            print("Error in concating dataframe for ingredient: ", ingredient_title)
            print("Error = ", e)
    # Save the final dataframe as csv file
    damn_delicious_recipes_df.to_csv(DIR_PATH+'damn_delicious_recipes.csv', index=False)
    damn_delicious_reviews_df.to_csv(DIR_PATH+'damn_delicious_reviews.csv', index=False)
    print("Finished!")

# %%
def main():
    scrape_dd()

# %%
main()
# Out:
# Start..
# ##################################################
# Reading recipes for Ingredient:  apple
# ##################################################
# Recipe Loaded successfully:  vanilla-glazed-apple-cinnamon-muffins
# No Recipe Found in  cinnamon-apple-dippers
# Error in loading recipes from page:  https://damndelicious.net/tag/apple/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  apple
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  asparagus
# ##################################################
# Recipe Loaded successfully:  bacon-wrapped-asparagus
# Recipe Loaded successfully:  prosciutto-wrapped-asparagus
# Recipe Loaded successfully:  asparagus-tart-with-balsamic-reduction
# Recipe Loaded successfully:  veggie-flatbread-pizza
# No Recipe Found in  creamy-meyer-lemon-pasta
# Error in loading recipes from page:  https://damndelicious.net/tag/asparagus/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  asparagus
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  avocado
# ##################################################
# Recipe Loaded successfully:  guacamole-breakfast-sandwich
# Recipe Loaded successfully:  avocado-grilled-cheese
# Recipe Loaded successfully:  bacon-avocado-pasta
# Recipe Loaded successfully:  avocado-pasta
# Recipe Loaded successfully:  cheesecake-factory-avocado-egg-rolls
# Recipe Loaded successfully:  shrimp-cobb-salad-cilantro-lime-vinaigrette
# Recipe Loaded successfully:  bbq-chicken-cobb-salad
# Recipe Loaded successfully:  enchilada-pasta
# Recipe Loaded successfully:  quinoa-chili
# Recipe Loaded successfully:  asian-style-nachos
# Recipe Loaded successfully:  one-pot-mexican-skillet-pasta
# Recipe Loaded successfully:  avocado-bruschetta-balsamic-reduction
# Recipe Loaded successfully:  breakfast-stuffed-sweet-potatoes
# Recipe Loaded successfully:  loaded-nachos
# Recipe Loaded successfully:  blat-hot-dogs
# Recipe Loaded successfully:  strawberry-avocado-couscous-with-lime-vinaigrette-2
# Recipe Loaded successfully:  sweet-corn-grilled-guacamole
# Recipe Loaded successfully:  strawberry-avocado-pico-de-gallo
# Recipe Loaded successfully:  sriracha-guacamole-hot-dogs
# Recipe Loaded successfully:  caprese-quinoa-salad
# Recipe Loaded successfully:  grilled-corn-salad-and-recipegirl-cookbook-giveaway
# Recipe Loaded successfully:  asian-pasta-salad
# Recipe Loaded successfully:  bacon-and-avocado-macaroni-salad
# Recipe Loaded successfully:  fried-avocado-with-chipotle-cream-sauce
# ##################################################
# Completed reading recipes for Ingredient:  avocado
# ##################################################
# ##################################################
# Reading recipes for Ingredient:
# Recipe Loaded successfully:  chicken-florentine-with-white-wine-cream-sauce
# Recipe Loaded successfully:  bbq-chicken-breasts
# Recipe Loaded successfully:  one-pot-chicken-ranch-pasta
# Recipe Loaded successfully:  honey-lemon-chicken-broccoli-bowls
# Recipe Loaded successfully:  chicken-pesto-kabobs
# Recipe Loaded successfully:  slow-cooker-garlic-parmesan-chicken-potatoes
# Recipe Loaded successfully:  baked-teriyaki-chicken-broccoli
# Recipe Loaded successfully:  thai-coconut-curry-chicken
# Recipe Loaded successfully:  bbq-chicken-bites
# Recipe Loaded successfully:  chicken-potatoes-garlic-parmesan-cream-sauce
# Recipe Loaded successfully:  chicken-tortellini-soup
# Recipe Loaded successfully:  one-pan-lemon-chicken-with-butternut-squash-and-brussels-sprouts
# Recipe Loaded successfully:  slow-cooker-pineapple-chicken
# Recipe Loaded successfully:  chicken-lazone
# ##################################################
# Completed reading recipes for Ingredient:  chicken
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken enchiladas
# ##################################################
# Recipe Loaded successfully:  weeknight-chicken-enchiladas
# ##################################################
# Completed reading recipes for Ingredient:  chicken enchiladas
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken enchiladas recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  chicken enchiladas recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken meal prep
# ##################################################
# Recipe Loaded successfully:  meal-prep-chicken-3-ways
# ##################################################
# Completed reading recipes for Ingredient:  chicken meal prep
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  Chicken meatball noodle soup
# ##################################################
# Recipe Loaded successfully:  chicken-meatball-noodle-soup
# ##################################################
# Completed reading recipes for Ingredient:  Chicken meatball noodle soup
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken meatball soup
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  chicken meatball soup
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken noodle recipe
# ##################################################
# Recipe Loaded successfully:  quick-chicken-ramen-noodle-stir-fry
# ##################################################
# Completed reading recipes for Ingredient:  chicken noodle recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken noodle soup
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  chicken noodle soup
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken ramen noodle recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  chicken ramen noodle recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken ramen noodles
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  chicken ramen noodles
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken recipe
# ##################################################
# Recipe Loaded successfully:  skillet-mushroom-chicken-thighs
# ##################################################
# Completed reading recipes for Ingredient:  chicken recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken soup
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  chicken soup
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chicken thigh recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  chicken thigh recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chinese
# ##################################################
# Recipe Loaded successfully:  lighter-general-tsos-chicken
# Recipe Loaded successfully:  firecracker-chicken
# Recipe Loaded successfully:  baked-sweet-sour-chicken
# Recipe Loaded successfully:  chinese-orange-chicken
# Recipe Loaded successfully:  honey-walnut-shrimp
# Recipe Loaded successfully:  sesame-chicken
# No Recipe Found in  pork-and-asparagus-with-hoisin-sauce
# Error in loading recipes from page:  https://damndelicious.net/tag/chinese/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  chinese
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  chocolate
# ##################################################
# Recipe Loaded successfully:  halloween-spider-cupcakes
# No Recipe Found in  mini-pumpkin-bundt-cakes-cinnamon-glaze
# Error in loading recipes from page:  https://damndelicious.net/tag/chocolate/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  chocolate
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  classic ham recipe
# ##################################################
# Recipe Loaded successfully:  maple-glazed-ham
# ##################################################
# Completed reading recipes for Ingredient:  classic ham recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  cookies
# ##################################################
# Recipe Loaded successfully:  brown-butter-chocolate-chip-cookie-skillet-pizookie
# Recipe Loaded successfully:  funfetti-cookies-with-chocolate-chunks-and-a-scharffen
# No Recipe Found in  mint-chocolate-chunk-cookies-and-a-giveaway
# Error in loading recipes from page:  https://damndelicious.net/tag/cookies/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  cookies
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  corn
# ##################################################
# Recipe Loaded successfully:  parmesan-corn-on-the-cob
# Recipe Loaded successfully:  mexican-corn-dip
# Recipe Loaded successfully:  bacon-corn-dip
# Recipe Loaded successfully:  mexican-corn-cob
# Recipe Loaded successfully:  leftover-hambone-soup
# Recipe Loaded successfully:  slow-cooker-creamed-corn
# Recipe Loaded successfully:  potato-corn-chowder
# Recipe Loaded successfully:  hot-cheesy-corn-dip
# Recipe Loaded successfully:  grilled-corn-mango-salsa
# Recipe Loaded successfully:  mexican-hot-dogs-with-chipotle-cream
# Recipe Loaded successfully:  avocado-corn-salsa
# Recipe Loaded successfully:  potato-corn-zucchini-chowder
# Recipe Loaded successfully:  spicy-chipotle-pesto-pasta
# ##################################################
# Completed reading recipes for Ingredient:  corn
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  cranberries
# ##################################################
# Recipe Loaded successfully:  sugared-cranberries
# Recipe Loaded successfully:  cranberry-orange-sauce
# Recipe Loaded successfully:  cranberry-margarita
# No Recipe Found in  whole-wheat-pancakes-with-cranberry-maple-syrup
# Error in loading recipes from page:  https://damndelicious.net/tag/cranberries/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  cranberries
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  cranberry sauce recipe
# ##################################################
# Recipe Loaded successfully:  instant-pot-cranberry-sauce
# ##################################################
# Completed reading recipes for Ingredient:  cranberry sauce recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  creamed corn
# ##################################################
# Recipe Loaded successfully:  stovetop-bacon-creamed-corn
# ##################################################
# Completed reading recipes for Ingredient:  creamed corn
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  creamed corn recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  creamed corn recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  creamy mushroom soup recipe
# ##################################################
# No Recipe Found in  creamy-roasted-mushroom-soup
# Error in loading recipes from page:  https://damndelicious.net/tag/creamy-mushroom-soup-recipe/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  creamy mushroom soup recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  creamy soup recipe
# ##################################################
# Recipe Loaded successfully:  creamy-tortellini-soup
# ##################################################
# Completed reading recipes for Ingredient:  creamy soup recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  creamy tortellini
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  creamy tortellini
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  creamy tortellini soup
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  creamy tortellini soup
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  cupcakes
# ##################################################
# Recipe Loaded successfully:  pumpkin-cheesecake-cupcakes
# Recipe Loaded successfully:  candy-corn-cupcakes
# Recipe Loaded successfully:  pumpkin-cupcakes-cinnamon-cream-cheese-frosting
# Recipe Loaded successfully:  fruity-pebble-cupcakes
# Recipe Loaded successfully:  strawberry-shortcake-cupcakes
# Recipe Loaded successfully:  mini-vanilla-bean-cupcakes-with-vanilla-buttercream
# No Recipe Found in  green-tea-cupcakes-with-matcha-cream-cheese-frosting
# Error in loading recipes from page:  https://damndelicious.net/tag/cupcakes/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  cupcakes
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  dinner roll recipe
# ##################################################
# Recipe Loaded successfully:  make-ahead-yeast-rolls
# ##################################################
# Completed reading recipes for Ingredient:  dinner roll recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  dinner yeast rolls
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  dinner yeast rolls
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  donuts
# ##################################################
# Recipe Loaded successfully:  pumpkin-donut-holes
# Recipe Loaded successfully:  baked-pumpkin-donuts-with-maple-glaze
# Recipe Loaded successfully:  pumpkin-doughnut-muffins
# Recipe Loaded successfully:  voskos-greek-yogurt-cinnamon-roll-donuts
# No Recipe Found in  lightened-up-pumpkin-donuts-with-maple-glaze
# Error in loading recipes from page:  https://damndelicious.net/tag/donuts/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  donuts
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  enchiladas
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  enchiladas
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  fish taco
# ##################################################
# Recipe Loaded successfully:  fish-taco-bowls
# ##################################################
# Completed reading recipes for Ingredient:  fish taco
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  fish taco bowl
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  fish taco bowl
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  fish tacos
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  fish tacos
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  garlic baked potatoes
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  garlic baked potatoes
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  garlic butter scallop recipe
# ##################################################
# Recipe Loaded successfully:  garlic-butter-scallop-bowls
# ##################################################
# Completed reading recipes for Ingredient:  garlic butter scallop recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  garlic butter shrimp
# ##################################################
# Recipe Loaded successfully:  garlic-butter-shrimp-scampi
# ##################################################
# Completed reading recipes for Ingredient:  garlic butter shrimp
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  garlic butter shrimp scampi
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  garlic butter shrimp scampi
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  Garlic scallop recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  Garlic scallop recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  glazed ham recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  glazed ham recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  gnocchi recipe
# ##################################################
# Recipe Loaded successfully:  brown-butter-sweet-potato-gnocchi
# ##################################################
# Completed reading recipes for Ingredient:  gnocchi recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  ham recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  ham recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  hambone soup recipe
# ##################################################
# Recipe Loaded successfully:  instant-pot-leftover-hambone-soup
# ##################################################
# Completed reading recipes for Ingredient:  hambone soup recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  hard boiled egg recipe
# ##################################################
# Recipe Loaded successfully:  instant-pot-perfect-hard-boiled-eggs
# ##################################################
# Completed reading recipes for Ingredient:  hard boiled egg recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  hard boiled eggs
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  hard boiled eggs
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  healthy zucchini recipes
# ##################################################
# No Recipe Found in  10-easy-and-healthy-zucchini-recipes
# Error in loading recipes from page:  https://damndelicious.net/tag/healthy-zucchini-recipes/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  healthy zucchini recipes
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  Homemade Ramen
# ##################################################
# Recipe Loaded successfully:  easy-homemade-ramen
# ##################################################
# Completed reading recipes for Ingredient:  Homemade Ramen
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  hot dog
# ##################################################
# Recipe Loaded successfully:  classic-pigs-blanket
# Recipe Loaded successfully:  bahn-mi-hot-dogs
# Recipe Loaded successfully:  hawaiian-hot-dogs-with-mango-salsa
# No Recipe Found in  bacon-wrapped-chili-cheese-dogs-sundaysupper
# Error in loading recipes from page:  https://damndelicious.net/tag/hot-dog/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  hot dog
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  ice cream
# ##################################################
# No Recipe Found in  outshine-fruit-bars
# Error in loading recipes from page:  https://damndelicious.net/tag/ice-cream/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  ice cream
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  instant pot
# ##################################################
# No Recipe Found in  10-best-instant-pot-recipes-for-everyone
# Error in loading recipes from page:  https://damndelicious.net/tag/instant-pot/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  instant pot
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  instant pot butternut squash recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  instant pot butternut squash recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  instant pot cranberry sauce recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  instant pot cranberry sauce recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  instant pot hambone recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  instant pot hambone recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  instant pot hard boiled egg recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  instant pot hard boiled egg recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  instant pot hard boiled eggs
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  instant pot hard boiled eggs
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  Instant Pot recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  Instant Pot recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  instant pot recipes
# ##################################################
# No Recipe Found in  10-best-instant-pot-recipes-for-everyone
# Error in loading recipes from page:  https://damndelicious.net/tag/instant-pot-recipes/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  instant pot recipes
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  instant pot Sweet potato casserole recipe
# ##################################################
# Recipe Loaded successfully:  instant-pot-sweet-potato-casserole
# ##################################################
# Completed reading recipes for Ingredient:  instant pot Sweet potato casserole recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  turkey slider recipes
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  yeast roll recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  yeast roll recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  zucchini
# ##################################################
# Recipe Loaded successfully:  sheet-pan-zucchini-parmesan
# Recipe Loaded successfully:  zucchini-parmesan-foil-packets
# Recipe Loaded successfully:  zucchini-alfredo
# Recipe Loaded successfully:  zucchini-tots
# No Recipe Found in  10-easy-and-healthy-zucchini-recipes
# Error in loading recipes from page:  https://damndelicious.net/tag/zucchini/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  zucchini
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  zucchini noodle recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  zucchini noodle recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  zucchini recipe
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  zucchini recipe
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  zucchini recipes
# ##################################################
# No Recipe Found in  10-easy-and-healthy-zucchini-recipes
# Error in loading recipes from page:  https://damndelicious.net/tag/zucchini-recipes/
# Error:  not enough values to unpack (expected 3, got 2)
# ##################################################
# Completed reading recipes for Ingredient:  zucchini recipes
# ##################################################
# ##################################################
# Reading recipes for Ingredient:  zuccini noodles
# ##################################################
# ##################################################
# Completed reading recipes for Ingredient:  zuccini noodles
# ##################################################
# Finished!

# %% [markdown]
# ## ETL

# %%
dd_rc_df = pd.read_csv("datasets/damn_delicious_recipes.csv")
dd_rc_df.head(5)
# Out:
#    recipe_id                                   title          date_posted  \
# 0          0   Vanilla Glazed Apple Cinnamon Muffins  2013-09-20T00:00:00
# 1          1                 Bacon Wrapped Asparagus  2016-05-21T00:00:00
# 2          2            Prosciutto Wrapped Asparagus  2013-12-27T00:00:00
# 3          3  Asparagus Tart with Balsamic Reduction  2013-05-13T00:00:00
# 4          4      Whole Wheat Veggie Flatbread Pizza  2013-03-22T00:00:00
#
#        yields   prep_time   cook_time  total_time  ratings  ratings_count  \
# 0   4 muffins  15 minutes  15 minutes  30 minutes      NaN            NaN
# 1  6 servings  10 minutes  20 minutes  30 minutes      4.5            2.0
# 2  4 servings  10 minutes   5 minutes  15 minutes      5.0            1.0
# 3  4 servings  10 minutes  25 minutes  35 minutes      NaN            NaN
# 4  6 servings  10 minutes  10 minutes  20 minutes      NaN            NaN
#
#    n_ingredients                                        ingredients  n_steps  \
# 0             13  ['1/2 cup all-purpose flour', '1 teaspoon baki...        7
# 1             10  ['1/2 cup unsalted butter, melted', '1/4 cup b...        7
# 2              3  ['6 ounces sliced prosciutto, halved horizonta...        3
# 3              7  ['1 sheet frozen puff pastry, thawed, cut into...        6
# 4              6  ['6 whole wheat Middle Eastern flatbreads', '1...        4
#
#                                           directions  \
# 0  ['Preheat oven to 350 degrees F. Coat a standa...
# 1  ['Preheat oven to 400 degrees F. Lightly oil a...
# 2  ['Working one at a time, wrap halved prosciutt...
# 3  ['Preheat oven to 400 degrees F. Line a baking...
# 4  ['Preheat oven to 375 degrees F. Line a baking...
#
#                                            nutrition  \
# 0                                                 []
# 1  [['Calories', '318.9'], ['Total Fat', '28.2g']...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                 tags
# 0                                      ['breakfast']
# 1                                      ['side dish']
# 2                                      ['appetizer']
# 3                        ['appetizer', 'vegetarian']
# 4  ['entree', 'healthy', 'quick & easy', 'vegetar...

# %%
# Characters to be deleted
delete_char = ['(',')','[',']','/','-','⁄','%','.','\n']

# Extra keywords to be omitted
extras = [
    'bag',
    'box',
    'bunch',
    'can',
    'cup',
    'cups',
    'dash',
    'dozen',
    'drop',
    'envelope',
    'fluid',
    'g',
    'gallon',
    'head',
    'inch',
    'jar',
    'kg',
    'kgs',
    'large',
    'lb',
    'lbs',
    'leaf',
    'liter',
    'loaf',
    'medium',
    'mg',
    'ml',
    'ounce',
    'ounces',
    'package',
    'packages',
    'packet',
    'packets',
    'pinch',
    'pint',
    'pints',
    'quart',
    'quarts',
    'scoop',
    'scoops',
    'sheet',
    'sheets',
    'slice',
    'slices',
    'small',
    'sprig',
    'sprigs',
    'stalk',
    'stalks',
    'tablespoon',
    'tablespoons',
    'teaspoon',
    'teaspoons',
    'whole'
]

# Remove the extra tokens
def remove_extras(string):
    
    string = str(string)
    for char in delete_char:
        string = string.replace(str(char), " ")
    
    tokens = string.split(" ")
    
    if tokens[0].strip().lower() == 'for':
        return ""
    
    string_list=[]
    for token in tokens:
        token = token.strip()
        if not token.isnumeric():
            if token not in extras:
                string_list.append(token)
    
    return (' '.join([elem for elem in string_list])).strip()

# %%
dd_rc = dd_rc_df.copy()
dd_rc = dd_rc.drop(['yields', 'prep_time', 'cook_time'], axis=1)
dd_rc['ratings'] = dd_rc['ratings'].fillna(0)
dd_rc['ratings_count'] = dd_rc['ratings_count'].fillna(0)
dd_rc['total_time'] = dd_rc['total_time'].fillna("0 minutes")
dd_rc['total_time'] = dd_rc['total_time'].apply(lambda x: x.split(" ")[0])

# %%
# Process the dataframe to transform ingredients
def process_ingredients(input_df):
    ingredients = input_df.copy()
    ingredients = ingredients[['ingredients','recipe_id']]
#     ingredients['ingredients'] = ingredients['ingredients'].astype(str)
#     ingredients['ingredients'] = ingredients['ingredients'].apply(lambda x: x.replace("empty", "0"))
    ingredients['ingredients'] = ingredients['ingredients'].apply(ast.literal_eval)
    ingredients = ingredients.explode('ingredients')
    ingredients['ingredients'] = ingredients['ingredients'].str.lower()
    ingredients['ingredients'] = ingredients['ingredients'].apply(remove_extras)
    ingredients = ingredients[ingredients["ingredients"] != ""]
#     ingredients = ingredients.explode('recipe_id')
    ingredients = ingredients.groupby(['recipe_id']).agg({'ingredients': lambda x: x.tolist()})
    ingredients = ingredients[ingredients['ingredients'] != ""]
    ingredients['ingredients'] = ingredients['ingredients'].astype(str)
    ingredients.reset_index(inplace=True)
    return ingredients

# %%
dd_rc_ig = dd_rc.copy()
dd_rc_ig = process_ingredients(dd_rc_ig)
dd_rc_ig.columns = ['id', 'ing']
dd_rc_fi = pd.merge(dd_rc, dd_rc_ig, how="left", left_on=["recipe_id"], right_on=["id"])
dd_rc_fi['ingredients'] = dd_rc_fi['ing']
dd_rc_fi = dd_rc_fi.drop(['id', 'ing'], axis=1)
dd_rc_fi.head(5)
# Out:
#    recipe_id                                   title          date_posted  \
# 0          0   Vanilla Glazed Apple Cinnamon Muffins  2013-09-20T00:00:00
# 1          1                 Bacon Wrapped Asparagus  2016-05-21T00:00:00
# 2          2            Prosciutto Wrapped Asparagus  2013-12-27T00:00:00
# 3          3  Asparagus Tart with Balsamic Reduction  2013-05-13T00:00:00
# 4          4      Whole Wheat Veggie Flatbread Pizza  2013-03-22T00:00:00
#
#   total_time  ratings  ratings_count  n_ingredients  \
# 0         30      0.0            0.0             13
# 1         30      4.5            2.0             10
# 2         15      5.0            1.0              3
# 3         35      0.0            0.0              7
# 4         20      0.0            0.0              6
#
#                                          ingredients  n_steps  \
# 0  ['all purpose flour', 'baking powder', 'cinnam...        7
# 1  ['unsalted butter, melted', 'brown sugar, pack...        7
# 2  ['sliced prosciutto, halved horizontally', 'po...        3
# 3  ['frozen puff pastry, thawed, cut into squares...        6
# 4  ['wheat middle eastern flatbreads', 'marinara ...        4
#
#                                           directions  \
# 0  ['Preheat oven to 350 degrees F. Coat a standa...
# 1  ['Preheat oven to 400 degrees F. Lightly oil a...
# 2  ['Working one at a time, wrap halved prosciutt...
# 3  ['Preheat oven to 400 degrees F. Line a baking...
# 4  ['Preheat oven to 375 degrees F. Line a baking...
#
#                                            nutrition  \
# 0                                                 []
# 1  [['Calories', '318.9'], ['Total Fat', '28.2g']...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                 tags
# 0                                      ['breakfast']
# 1                                      ['side dish']
# 2                                      ['appetizer']
# 3                        ['appetizer', 'vegetarian']
# 4  ['entree', 'healthy', 'quick & easy', 'vegetar...

# %%
def get_num(item):
    item = item.replace("g", "")    
    item = item.replace("mg", "")
    item = item.replace("m", "")
    return item

# %%
# Process the dataframe to transform ingredients
def process_nutrition(input_df):
    nutrition = input_df.copy()
    nutrition = nutrition[['nutrition','recipe_id']]
    nutrition['nutrition'] = nutrition['nutrition'].astype(str)
    nutrition = nutrition[nutrition['nutrition'] != "[]"]
    nutrition['nutrition'] = nutrition['nutrition'].apply(ast.literal_eval)
    nutrition = nutrition.explode('nutrition')
    nutrition['nutrition'] = nutrition['nutrition'].apply(lambda x: x[1] if len(x) > 1 else [])
    nutrition['nutrition'] = nutrition['nutrition'].astype(str).apply(get_num)
    nutrition = nutrition.groupby(['recipe_id']).agg({'nutrition': lambda x: x.tolist()})
    nutrition['nutrition'] = nutrition['nutrition'].astype(str)
    nutrition.reset_index(inplace=True)
    return nutrition

# %%
dd_rc_nu = dd_rc_fi.copy()
dd_rc_nu = process_nutrition(dd_rc_nu)
dd_rc_nu.columns = ['id', 'nut']
dd_rc_nut = pd.merge(dd_rc_fi, dd_rc_nu, how='left', left_on=["recipe_id"], right_on=["id"])
dd_rc_nut['nutrition'] = dd_rc_nut['nut']
dd_rc_nut = dd_rc_nut.drop(['id', 'nut'], axis=1)
dd_rc_nut['nutrition'] = dd_rc_nut['nutrition'].fillna("[]")
dd_rc_nut.head(5)
# Out:
#    recipe_id                                   title          date_posted  \
# 0          0   Vanilla Glazed Apple Cinnamon Muffins  2013-09-20T00:00:00
# 1          1                 Bacon Wrapped Asparagus  2016-05-21T00:00:00
# 2          2            Prosciutto Wrapped Asparagus  2013-12-27T00:00:00
# 3          3  Asparagus Tart with Balsamic Reduction  2013-05-13T00:00:00
# 4          4      Whole Wheat Veggie Flatbread Pizza  2013-03-22T00:00:00
#
#   total_time  ratings  ratings_count  n_ingredients  \
# 0         30      0.0            0.0             13
# 1         30      4.5            2.0             10
# 2         15      5.0            1.0              3
# 3         35      0.0            0.0              7
# 4         20      0.0            0.0              6
#
#                                          ingredients  n_steps  \
# 0  ['all purpose flour', 'baking powder', 'cinnam...        7
# 1  ['unsalted butter, melted', 'brown sugar, pack...        7
# 2  ['sliced prosciutto, halved horizontally', 'po...        3
# 3  ['frozen puff pastry, thawed, cut into squares...        6
# 4  ['wheat middle eastern flatbreads', 'marinara ...        4
#
#                                           directions  \
# 0  ['Preheat oven to 350 degrees F. Coat a standa...
# 1  ['Preheat oven to 400 degrees F. Lightly oil a...
# 2  ['Working one at a time, wrap halved prosciutt...
# 3  ['Preheat oven to 400 degrees F. Line a baking...
# 4  ['Preheat oven to 375 degrees F. Line a baking...
#
#                                            nutrition  \
# 0                                                 []
# 1  ['318.9', '28.2', '13.0', '48.4', '69.4', '15....
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                 tags
# 0                                      ['breakfast']
# 1                                      ['side dish']
# 2                                      ['appetizer']
# 3                        ['appetizer', 'vegetarian']
# 4  ['entree', 'healthy', 'quick & easy', 'vegetar...

# %%
dd_rc_copy = dd_rc_nut.copy()
dd_rc_copy.columns = [
    'id',
    'name', 
    'submitted', 
    'minutes', 
    'ratings', 
    'ratings_count',
    'n_ingredients', 
    'ingredients', 
    'n_steps', 
    'steps', 
    'nutrition', 
    'tags'
]
display(dd_rc_copy)
# Out:
#       id                                       name            submitted  \
# 0      0      Vanilla Glazed Apple Cinnamon Muffins  2013-09-20T00:00:00
# 1      1                    Bacon Wrapped Asparagus  2016-05-21T00:00:00
# 2      2               Prosciutto Wrapped Asparagus  2013-12-27T00:00:00
# 3      3     Asparagus Tart with Balsamic Reduction  2013-05-13T00:00:00
# 4      4         Whole Wheat Veggie Flatbread Pizza  2013-03-22T00:00:00
# ..   ...                                        ...                  ...
# 377  377  Leftover Thanksgiving Turkey Pesto Panini  2012-11-21T00:00:00
# 378  378                Sheet Pan Zucchini Parmesan  2017-04-25T00:00:00
# 379  379             Zucchini Parmesan Foil Packets  2016-07-19T00:00:00
# 380  380                           Zucchini Alfredo  2016-01-17T00:00:00
# 381  381                              Zucchini Tots  2015-08-08T00:00:00
#
#     minutes  ratings  ratings_count  n_ingredients  \
# 0        30     0.00            0.0             13
# 1        30     4.50            2.0             10
# 2        15     5.00            1.0              3
# 3        35     0.00            0.0              7
# 4        20     0.00            0.0              6
# ..      ...      ...            ...            ...
# 377      15     0.00            0.0              7
# 378      40     5.00            5.0              9
# 379      25     5.00            5.0              8
# 380      30     4.33            3.0             11
# 381      40     5.00            3.0             14
#
#                                            ingredients  n_steps  \
# 0    ['all purpose flour', 'baking powder', 'cinnam...        7
# 1    ['unsalted butter, melted', 'brown sugar, pack...        7
# 2    ['sliced prosciutto, halved horizontally', 'po...        3
# 3    ['frozen puff pastry, thawed, cut into squares...        6
# 4    ['wheat middle eastern flatbreads', 'marinara ...        4
# ..                                                 ...      ...
# 377  ['olive oil', 'of french bread, cut into equal...        3
# 378  ['panko*', 'freshly grated parmesan cheese', '...        7
# 379  ['unsalted butter, melted', 'freshly grated pa...        5
# 380  ['unsalted butter, divided', 'pound  sized  zu...        5
# 381  ['zucchini, shredded', 'salt', 'carrots, peele...        6
#
#                                                  steps  \
# 0    ['Preheat oven to 350 degrees F. Coat a standa...
# 1    ['Preheat oven to 400 degrees F. Lightly oil a...
# 2    ['Working one at a time, wrap halved prosciutt...
# 3    ['Preheat oven to 400 degrees F. Line a baking...
# 4    ['Preheat oven to 375 degrees F. Line a baking...
# ..                                                 ...
# 377  ['Heat olive oil in a grill pan over medium-hi...
# 378  ['Preheat oven to 400 degrees F. Lightly oil a...
# 379  ['PREHEAT a gas or charcoal grill over high he...
# 380  ['Melt 1 tablespoon butter in a saucepan over ...
# 381  ['Preheat oven to 400 degrees F. Lightly oil a...
#
#                                              nutrition  \
# 0                                                   []
# 1    ['318.9', '28.2', '13.0', '48.4', '69.4', '15....
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 377                                                 []
# 378                                                 []
# 379  ['163.6', '13.9', '8.5', '35.0', '124.5', '6.9...
# 380  ['203.6', '14.2', '8.3', '39.5', '168.5', '12....
# 381  ['88.6', '4.9', '2', '67.5', '119.1', '8.3', '...
#
#                                                   tags
# 0                                        ['breakfast']
# 1                                        ['side dish']
# 2                                        ['appetizer']
# 3                          ['appetizer', 'vegetarian']
# 4    ['entree', 'healthy', 'quick & easy', 'vegetar...
# ..                                                 ...
# 377         ['entree', 'quick & easy', 'thanksgiving']
# 378                           ['appetizer', 'one pot']
# 379                                      ['side dish']
# 380              ['entree', 'healthy', 'quick & easy']
# 381                        ['appetizer', 'vegetarian']
#
# [382 rows x 12 columns]

# %%
dd_rv_df = pd.read_csv("datasets/damn_delicious_reviews.csv")
dd_rv_df.columns = ['recipe_id', 'user_id', 'date', 'rating', 'review']
dd_rv_df = dd_rv_df[['user_id', 'recipe_id', 'date', 'rating', 'review']]
dd_rv_df['rating'] = dd_rv_df['rating'].fillna(0)
dd_rv_df['date'] = dd_rv_df['date'].fillna("2022-01-01T00:00:00+00:00")
dd_rv_df['review'] = dd_rv_df['review'].fillna(" ")
dd_rv_df.head(5)
# Out:
#    user_id  recipe_id                       date  rating  \
# 0  Krystle          0  2016-11-02T13:04:59-07:00     0.0
# 1     Jess          0  2022-01-01T00:00:00+00:00     0.0
# 2   Rachel          0  2022-01-01T00:00:00+00:00     0.0
# 3   Nicola          0  2014-10-26T14:17:08-07:00     0.0
# 4    Maria          0  2014-07-12T18:31:09-07:00     0.0
#
#                                               review
# 0  Totally bummed to make this and find that I on...
# 1  I absolutely love this recipe! So much so I ad...
# 2  Muffins. I. love. Muffins. Maybe it’s the carb...
# 3  Did you really mean only half a cup of flour? ...
# 4  According to the proportions in the recipe how...

# %%
if not os.path.exists("temp/"):
        os.makedirs("temp/")
dd_rc_copy.to_csv('temp/damn_delicious_recipes.csv', index=False)
dd_rv_df.to_csv('temp/damn_delicious_reviews.csv', index=False)

# %% [markdown]
# # FIN
