# %%
import pandas as pd
import torch
import numpy as np
import random
from rbm import RBM


reviews = pd.read_csv('reviews.csv')
recipes = pd.read_csv('recipes.csv')

# %%
reviews.head()
# Out:
#    user_id  recipe_id        date  rating  \
# 0    38094      40893  2003-02-17       4
# 1  1293707      40893  2011-12-21       5
# 2     8937      44394  2002-12-01       4
# 3   126440      85009  2010-02-27       5
# 4    57222      85009  2011-10-01       5
#
#                                               review
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
# 2  This worked very well and is EASY.  I used not...
# 3  I made the Mexican topping and took it to bunk...
# 4  Made the cheddar bacon topping, adding a sprin...

# %%
recipes.index
# Out:
# RangeIndex(start=0, stop=231637, step=1)

# %%
# reviews.merge(recipes, how='inner', left_on='recipe_id', right_on='id')

# %%
df = reviews[['user_id', 'recipe_id']]

# %%
df
# Out:
#             user_id  recipe_id
# 0             38094      40893
# 1           1293707      40893
# 2              8937      44394
# 3            126440      85009
# 4             57222      85009
# ...             ...        ...
# 1132362      116593      72730
# 1132363      583662     386618
# 1132364      157126      78003
# 1132365       53932      78003
# 1132366  2001868099      78003
#
# [1132367 rows x 2 columns]

# %%
num_vis =  len(df)
rbm = RBM(0.01, 188, num_vis)

reviews = reviews.iloc[:5000,:]

unique_att = reviews['recipe_id'].unique()

unique_att.sort()
att_index = [i for i in range(len(unique_att))]
rbm_att_df = pd.DataFrame(list(zip(att_index,unique_att)), columns =['rbm_att_id','recipe_id'])
print(reviews)
joined = reviews.merge(rbm_att_df, on='recipe_id')
# print(joined)

# %%
joined = joined[['user_id','recipe_id','rbm_att_id','rating']]
readers_group = joined.groupby('user_id')

total = []
for readerID, curReader in readers_group:
    temp = np.zeros(len(reviews))
    for num, book in curReader.iterrows():
        temp[book['rbm_att_id']] = book['rating']
    total.append(temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lw/4hhwbl4d4q1dfpb0z8l91sr40000gn/T/ipykernel_1352/57983169.py in <module>
# ----> 1 joined = joined[['user_id','recipe_id','rbm_att_id','rating']]
#       2 readers_group = joined.groupby('user_id')
#       3
#       4 total = []
#       5 for readerID, curReader in readers_group:
#
# NameError: name 'joined' is not defined

# %%
total
# Out:
# [array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([5., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
# ...

# %%
len(total)
# Out:
# 3447

# %%
len(total[0])
# Out:
# 5000

# %%
total_data = total
random.shuffle(total_data)
n = len(total_data)
print("Total size of the data is: {0}".format(n))
size_train = int(n * 0.75)
X_train = total_data[:size_train]
X_valid = total_data[size_train:]
train, valid = X_train, X_valid
print("Size of the training data is: {0}".format(len(X_train)))
print("Size of the validation data is: {0}".format(len(X_valid)))
# Out:
# Total size of the data is: 3447
# Size of the training data is: 2585
# Size of the validation data is: 862

# %%
rbm.training(train, valid, 1, '100', 8, True, True, 'filename')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/lw/4hhwbl4d4q1dfpb0z8l91sr40000gn/T/ipykernel_98043/188880391.py in <module>
# ----> 1 rbm.training(train, valid, 1, '100', 8, True, True, 'filename')
#
# AttributeError: 'RBM' object has no attribute 'training'
